# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import itertools
from sklearn.metrics import confusion_matrix
from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# # Summary
#
# Face recognition models are regular convolutional neural networks models. They represent face photos as vectors. We find the distance between these two vectors to compare two faces. Finally, we classify two faces as same person whose distance is less than a threshold value.
#
# The question is that how to determine the threshold. In this notebook, we will find the best split point for a threshold.

# %% [markdown]
# # 1. 동양인 데이터
# - 같은 사람 3000 pairs, 다른 사람 3000 pairs

# %%
df1 = pd.read_csv('/content/drive/My Drive/기업프로젝트-라젠/deepface/tests/pair_with_dist_l2.csv')
del df1['distance'], df1['distance_l2']
df1
# Out:
#                                                  file_x  ... decision
# 0     /content/drive/My Drive/기업프로젝트-라젠/d...  ...      Yes
# 1     /content/drive/My Drive/기업프로젝트-라젠/d...  ...      Yes
# 2     /content/drive/My Drive/기업프로젝트-라젠/d...  ...      Yes
# 3     /content/drive/My Drive/기업프로젝트-라젠/d...  ...      Yes
# 4     /content/drive/My Drive/기업프로젝트-라젠/d...  ...      Yes
# ...                                                 ...  ...      ...
# 5995  /content/drive/My Drive/기업프로젝트-라젠/d...  ...       No
# 5996  /content/drive/My Drive/기업프로젝트-라젠/d...  ...       No
# 5997  /content/drive/My Drive/기업프로젝트-라젠/d...  ...       No
# 5998  /content/drive/My Drive/기업프로젝트-라젠/d...  ...       No
# 5999  /content/drive/My Drive/기업프로젝트-라젠/d...  ...       No
#
# [6000 rows x 3 columns]

# %%
import os
os.getcwd()
os.chdir("/content/drive/My Drive/기업프로젝트-라젠/deepface/")

# %%
# !pip install mtcnn
from deepface import DeepFace
# Out:
# Collecting mtcnn
#   Downloading https://files.pythonhosted.org/packages/67/43/abee91792797c609c1bf30f1112117f7a87a713ebaa6ec5201d5555a73ef/mtcnn-0.1.0-py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 12.7MB/s
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from mtcnn) (2.4.3)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from mtcnn) (4.1.2.30)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras>=2.0.0->mtcnn) (1.15.0)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.0
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
os.getcwd()
os.chdir('/content/drive/My Drive/기업프로젝트-라젠/deepface/deepface/')

# %%
import tensorflow as tf
import tensorflow_addons as tfa

instances = df1[["file_x", "file_y"]].values.tolist()
model_name = "mobilenet"
distance_metric = "euclidean_l2"
resp_obj = DeepFace.verify(instances, model_name = model_name, distance_metric = distance_metric, enforce_detection=False)
# 1시간 걸림(6000 pairs)
# Out:
# Using mobilenet_v2 model backend and euclidean_l2 distance.
# Verification: 100%|██████████| 6000/6000 [50:13<00:00,  1.99it/s]

# %%
distances = []
for i in range(0, len(instances)):
    distance = round(resp_obj["pair_%s" % (i+1)]["distance"], 4)
    distances.append(distance)

# %%
df1["distance_l2"] = distances

# %%
df1[df1.decision == "Yes"].distance_l2.plot.kde()
df1[df1.decision == "No"].distance_l2.plot.kde()

# %%
df1['distance_l2_scaled'] = -df1['distance_l2']

# %%
df1
# Out:
#                                                  file_x  ... distance_l2_scaled
# 0     /content/drive/My Drive/기업프로젝트-라젠/d...  ...            -1.5167
# 1     /content/drive/My Drive/기업프로젝트-라젠/d...  ...            -0.6777
# 2     /content/drive/My Drive/기업프로젝트-라젠/d...  ...            -0.5227
# 3     /content/drive/My Drive/기업프로젝트-라젠/d...  ...            -0.0998
# 4     /content/drive/My Drive/기업프로젝트-라젠/d...  ...            -1.3446
# ...                                                 ...  ...                ...
# 5995  /content/drive/My Drive/기업프로젝트-라젠/d...  ...            -1.3609
# 5996  /content/drive/My Drive/기업프로젝트-라젠/d...  ...            -1.1748
# 5997  /content/drive/My Drive/기업프로젝트-라젠/d...  ...            -1.4024
# 5998  /content/drive/My Drive/기업프로젝트-라젠/d...  ...            -0.2220
# 5999  /content/drive/My Drive/기업프로젝트-라젠/d...  ...            -0.1507
#
# [6000 rows x 5 columns]

# %%
# df1.to_csv('/content/drive/My Drive/기업프로젝트-라젠/deepface/tests/outputs/pair_with_dist_Asian_6000_non_cropped_mobilenet.csv', index=False)

# %% [markdown]
# # ROC curve

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_curve, auc
from scipy import interp
from sklearn.metrics import roc_auc_score

# %%
encoder = LabelEncoder()
encoder.fit(df1['decision'])
df1['y'] = encoder.transform(df1['decision']) # 1='Yes' / 0='No'
df1['y']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5995    0
# 5996    0
# 5997    0
# 5998    0
# 5999    0
# Name: y, Length: 6000, dtype: int64

# %%
fpr, tpr, thresholds = roc_curve(df1['y'], df1['distance_l2_scaled'], pos_label=1)
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve(mobilenet_v2.h5)-Asian')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # threshold
# - not using k-fold

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_curve, auc
from scipy import interp
from sklearn.metrics import roc_auc_score
from sklearn.tree import DecisionTreeClassifier

import graphviz
from sklearn.tree import export_graphviz

# %%
clf1 = DecisionTreeClassifier(max_depth=1)
X = np.array(df1['distance_l2']).reshape(-1, 1)
y = np.array(df1['y']).reshape(-1, 1)
clf1.fit(X, y)
print(clf1.score(X, y))
# Out:
# 0.5078333333333334

# %%
export_graphviz(clf1, out_file='clf1.dot', class_names=['불일치', '일치'], impurity=True, filled=True)
with open('clf1.dot') as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %%
threshold = clf1.tree_.threshold[0]

# %%
df1["pred_euclidean_l2"] = "No"

idx = df1[df1.distance_l2 <= threshold].index
df1.loc[idx, 'pred_euclidean_l2'] = 'Yes'

# %%
cm = confusion_matrix(df1.decision.values, df1.pred_euclidean_l2.values)
cm
# Out:
# array([[  56, 2944],
#        [   9, 2991]])

# %%
tn, fp, fn, tp = cm.ravel()
tn, fp, fn, tp
# Out:
# (56, 2944, 9, 2991)

# %%
recall = tp / (tp + fn)
precision = tp / (tp + fp)
accuracy = (tp + tn)/(tn + fp +  fn + tp)
f1 = 2 * (precision * recall) / (precision + recall)

# %%
print("Precision: ", 100*precision,"%")
print("Recall: ", 100*recall,"%")
print("F1 score ",100*f1, "%")
print("Accuracy: ", 100*accuracy,"%")
# Out:
# Precision:  50.395956192080874 %
# Recall:  99.7 %
# F1 score  66.95019585898153 %
# Accuracy:  50.78333333333334 %

# %% [markdown]
# ---
#
# # 2. lfw 데이터

# %%
df2 = pd.read_csv('/content/drive/My Drive/기업프로젝트-라젠/deepface/tests/pair_with_dist_lfw.csv')
del df2['distance_l2']
df2
# Out:
#                                                  file_x  ... decision
# 0     /content/drive/My Drive/main_proj/라젠/deepfa...  ...      Yes
# 1     /content/drive/My Drive/main_proj/라젠/deepfa...  ...      Yes
# 2     /content/drive/My Drive/main_proj/라젠/deepfa...  ...      Yes
# 3     /content/drive/My Drive/main_proj/라젠/deepfa...  ...      Yes
# 4     /content/drive/My Drive/main_proj/라젠/deepfa...  ...      Yes
# ...                                                 ...  ...      ...
# 5995  /content/drive/My Drive/main_proj/라젠/deepfa...  ...       No
# 5996  /content/drive/My Drive/main_proj/라젠/deepfa...  ...       No
# 5997  /content/drive/My Drive/main_proj/라젠/deepfa...  ...       No
# 5998  /content/drive/My Drive/main_proj/라젠/deepfa...  ...       No
# 5999  /content/drive/My Drive/main_proj/라젠/deepfa...  ...       No
#
# [6000 rows x 3 columns]

# %%
a = '/content/drive/My Drive/main_proj/라젠/deepface/tests/lfw_funneled_samples/'
b = '/content/drive/My Drive/기업프로젝트-라젠/deepface/tests/lfw_funneled_samples/'

df2['file_x'] = df2['file_x'].apply(lambda x: x.replace(a, b))
df2['file_y'] = df2['file_y'].apply(lambda x: x.replace(a, b))

# %%
df2
# Out:
#                                                  file_x  ... decision
# 0     /content/drive/My Drive/기업프로젝트-라젠/d...  ...      Yes
# 1     /content/drive/My Drive/기업프로젝트-라젠/d...  ...      Yes
# 2     /content/drive/My Drive/기업프로젝트-라젠/d...  ...      Yes
# 3     /content/drive/My Drive/기업프로젝트-라젠/d...  ...      Yes
# 4     /content/drive/My Drive/기업프로젝트-라젠/d...  ...      Yes
# ...                                                 ...  ...      ...
# 5995  /content/drive/My Drive/기업프로젝트-라젠/d...  ...       No
# 5996  /content/drive/My Drive/기업프로젝트-라젠/d...  ...       No
# 5997  /content/drive/My Drive/기업프로젝트-라젠/d...  ...       No
# 5998  /content/drive/My Drive/기업프로젝트-라젠/d...  ...       No
# 5999  /content/drive/My Drive/기업프로젝트-라젠/d...  ...       No
#
# [6000 rows x 3 columns]

# %%
os.getcwd()
os.chdir("/content/drive/My Drive/기업프로젝트-라젠/deepface/")

# %%
from deepface import DeepFace

# %%
import tensorflow as tf
import tensorflow_addons as tfa

instances = df2[["file_x", "file_y"]].values.tolist()
model_name = "mobilenet"
distance_metric = "euclidean_l2"
resp_obj = DeepFace.verify(instances, model_name = model_name, distance_metric = distance_metric, enforce_detection=False)
# Out:
# Using mobilenet_v2 model backend and euclidean_l2 distance.
# Verification: 100%|██████████| 6000/6000 [28:03<00:00,  3.57it/s]

# %%
distances = []
for i in range(0, len(instances)):
    distance = round(resp_obj["pair_%s" % (i+1)]["distance"], 4)
    distances.append(distance)
df2["distance_l2"] = distances

# %%
df2[df2.decision == "Yes"].distance_l2.plot.kde()
df2[df2.decision == "No"].distance_l2.plot.kde()

# %%
df2.to_csv('/content/drive/My Drive/기업프로젝트-라젠/deepface/tests/outputs/pair_with_dist_Asian_6000_non_cropped_mobilenet.csv', index=False)

# %% [markdown]
# # ROC curve

# %%
df2['distance_l2_scaled'] = -df2['distance_l2']

# %%
encoder = LabelEncoder()
encoder.fit(df2['decision'])
df2['y'] = encoder.transform(df2['decision']) # 1='Yes' / 0='No'
df2['y']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5995    0
# 5996    0
# 5997    0
# 5998    0
# 5999    0
# Name: y, Length: 6000, dtype: int64

# %%
fpr, tpr, thresholds = roc_curve(df2['y'], df2['distance_l2_scaled'], pos_label=1)
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve(mobilenet_v2.h5)-lfw')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Threshold

# %%
clf2 = DecisionTreeClassifier(max_depth=1)
X = np.array(df2['distance_l2']).reshape(-1, 1)
y = np.array(df2['y']).reshape(-1, 1)
clf2.fit(X, y)
print(clf2.score(X, y))
# Out:
# 0.5501666666666667

# %%
export_graphviz(clf2, out_file='clf2.dot', class_names=['불일치', '일치'], impurity=True, filled=True)
with open('clf2.dot') as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %%
threshold = clf2.tree_.threshold[0]

# %%
df2["pred_euclidean_l2"] = "No"

idx = df2[df2.distance_l2 <= threshold].index
df2.loc[idx, 'pred_euclidean_l2'] = 'Yes'

# %%
df2.sample(5)
# Out:
#                                                  file_x  ... pred_euclidean_l2
# 5462  /content/drive/My Drive/기업프로젝트-라젠/d...  ...                No
# 137   /content/drive/My Drive/기업프로젝트-라젠/d...  ...                No
# 4148  /content/drive/My Drive/기업프로젝트-라젠/d...  ...                No
# 4067  /content/drive/My Drive/기업프로젝트-라젠/d...  ...                No
# 3389  /content/drive/My Drive/기업프로젝트-라젠/d...  ...                No
#
# [5 rows x 7 columns]

# %%
cm = confusion_matrix(df2.decision.values, df2.pred_euclidean_l2.values)
cm
# Out:
# array([[2393,  607],
#        [2694,  306]])

# %%
tn, fp, fn, tp = cm.ravel()
tn, fp, fn, tp
# Out:
# (2393, 607, 2694, 306)

# %%
recall = tp / (tp + fn)
precision = tp / (tp + fp)
accuracy = (tp + tn)/(tn + fp +  fn + tp)
f1 = 2 * (precision * recall) / (precision + recall)

print("Precision: ", 100*precision,"%")
print("Recall: ", 100*recall,"%")
print("F1 score ",100*f1, "%")
print("Accuracy: ", 100*accuracy,"%")
# Out:
# Precision:  33.51588170865279 %
# Recall:  10.2 %
# F1 score  15.640173779708666 %
# Accuracy:  44.983333333333334 %
